# %%
# %cd /content/drive/MyDrive/pothol
# Out:
# /content/drive/MyDrive/pothol

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !yolo train batch=8 data=/content/drive/MyDrive/pothol/data.yaml model=yolov8l.pt epochs=100 name=experiment1
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 130MB/s]
# Ultralytics YOLOv8.0.104 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train batch=8 data=/content/drive/MyDrive/pothol/data.yaml model=/content/drive/MyDrive/pothol/runs/detect/experiment1/weights/last.pt epochs=100 name=experiment1  resume=True
# Out:
# Ultralytics YOLOv8.0.104 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
